# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import os

os.chdir(r'\\chem.ox.ac.uk\Research\Vallance Claire\Zhihao\Data\SO2\simulation\S3_O2_O2\Scan')

# Constants
k = 8.987155e9          # Coulomb constant [N m² C⁻²]
dt = 0.5 * 1e-15              # Time step in seconds
num_steps = 200000       # Number of integration steps

# Masses (in kg)
m1 = 32.0 * 1.67377e-27  # Mass of ion 1
m2 = 16.0 * 1.67377e-27  # Mass of ion 2
m3 = 16.0 * 1.67377e-27  # Mass of ion 3

# Charges (in Coulombs)
Q1 = 3 * 1.602e-19      # Charge of ion 1
Q2 = 2 * 1.602e-19      # Charge of ion 2
Q3 = 2 * 1.602e-19      # Charge of ion 3

# %%
def calculate_acceleration(r1, r2, r3, Q1_t, Q2_t, Q3_t):
    """
    Calculate the acceleration of each ion due to Coulomb forces.
    """
    # Pre-calculate difference vectors and their norms
    diff12 = r1 - r2
    diff13 = r1 - r3
    diff21 = -diff12   # r2 - r1
    diff23 = r2 - r3
    diff31 = -diff13   # r3 - r1
    diff32 = -diff23   # r3 - r2

    # Compute norms raised to the third power
    norm12_cubed = np.linalg.norm(diff12)**3
    norm13_cubed = np.linalg.norm(diff13)**3
    norm23_cubed = np.linalg.norm(diff23)**3

    # Calculate accelerations using Coulomb force law
    a1 = k / m1 * (Q1_t * Q2_t * diff12 / norm12_cubed +
                   Q1_t * Q3_t * diff13 / norm13_cubed)
    a2 = k / m2 * (Q2_t * Q1_t * (-diff12) / norm12_cubed +
                   Q2_t * Q3_t * diff23 / norm23_cubed)
    a3 = k / m3 * (Q1_t * Q3_t * (-diff13) / norm13_cubed +
                   Q2_t * Q3_t * (-diff23) / norm23_cubed)
    return a1, a2, a3

def calculate_first_step_r(r, v, a):
    """Calculate the position at the first time step using the Verlet algorithm."""
    return r + v * dt + 0.5 * a * dt**2

def simulate_run(R, Theta):
    """
    Simulate the system for given initial geometry (R in Å and Theta in °).
    The Verlet integration loop is executed, and only the final momenta
    and OSO angle are printed and returned.
    """
    factor = 1e-10  # Conversion from Å to m

    # Initial positions (in meters)
    r1 = np.array([0.0, 0.0])
    angle_rad = math.radians(Theta * 0.5)
    r2 = np.array([R * math.sin(angle_rad), -R * math.cos(angle_rad)]) * factor
    r3 = np.array([-R * math.sin(angle_rad), -R * math.cos(angle_rad)]) * factor

    # Initial velocities (m/s)
    v1 = np.array([0.0, 0.0])
    v2 = np.array([0.0, 0.0])
    v3 = np.array([0.0, 0.0])

    # Initial acceleration and first step positions
    a1, a2, a3 = calculate_acceleration(r1, r2, r3, Q1, Q2, Q3)
    r1_new = calculate_first_step_r(r1, v1, a1)
    r2_new = calculate_first_step_r(r2, v2, a2)
    r3_new = calculate_first_step_r(r3, v3, a3)

    # Initialize positions for Verlet integration
    r1_old, r2_old, r3_old = r1, r2, r3
    r1_now, r2_now, r3_now = r1_new, r2_new, r3_new

    # Verlet integration loop
    for step in range(2, num_steps):
        a1_now, a2_now, a3_now = calculate_acceleration(r1_now, r2_now, r3_now, Q1, Q2, Q3)
        r1_new = 2 * r1_now - r1_old + a1_now * dt**2
        r2_new = 2 * r2_now - r2_old + a2_now * dt**2
        r3_new = 2 * r3_now - r3_old + a3_now * dt**2

        # Update velocities (central difference)
        v1 = 0.5 * (r1_new - r1_old) / dt
        v2 = 0.5 * (r2_new - r2_old) / dt
        v3 = 0.5 * (r3_new - r3_old) / dt

        # Prepare for next iteration
        r1_old, r2_old, r3_old = r1_now, r2_now, r3_now
        r1_now, r2_now, r3_now = r1_new, r2_new, r3_new

    # # Final momenta (in kg·m/s)
    # P1 = m1 * np.linalg.norm(v1)
    # P2 = m2 * np.linalg.norm(v2)
    # P3 = m3 * np.linalg.norm(v3)
    # # Convert momenta to atomic units (1 a.u. = 1.99285e-24 kg·m/s)
    # P1_au = P1 / (1.99285e-24)
    # P2_au = P2 / (1.99285e-24)
    # P3_au = P3 / (1.99285e-24)


    # Calculate momentum components for each ion
    p1_x_au = m1 * v1[0]/ (1.99285e-24)
    p1_y_au = m1 * v1[1]/ (1.99285e-24)
    p2_x_au = m2 * v2[0]/ (1.99285e-24)
    p2_y_au = m2 * v2[1]/ (1.99285e-24)
    p3_x_au = m3 * v3[0]/ (1.99285e-24)
    p3_y_au = m3 * v3[1]/ (1.99285e-24)



    # Calculate OSO angle (in degrees) from ion 3's final velocity.
    OSO_angle = -math.degrees(math.atan2(v3[0], v3[1]))

    # Print final result for this run
    print(f"Final results for R = {R} Å, Theta = {Theta}°:")
    print(f"  O1_x momentum = {p2_x_au:.3e} a.u..")
    #print(f"  S momentum = {P1_au:.3e} a.u., O1 momentum = {P2_au:.3e} a.u., O2 momentum = {P3_au:.3e} a.u.")
    print(f"  OSO angle = {OSO_angle:.2f}°\n")

    return {
        'R_A': R,
        'Theta_deg': Theta,
        'momentum_S_x_au': p1_x_au,
        'momentum_S_y_au': p1_y_au,
        'momentum_O1_x_au': p2_x_au,
        'momentum_O1_y_au': p2_y_au,
        'momentum_O2_x_au': p3_x_au,
        'momentum_O2_y_au': p3_y_au,
        'OSO_angle_deg': OSO_angle
    }

# %%
def main_simulation():
    """
    Run the simulation for a range of R and Theta values, collect the final results,
    and save them to a CSV file.
    """
    results = []
    for R in np.arange(1.4, 3.2, 0.3):
        for Theta in np.arange(90, 140, 5):
            result = simulate_run(R, Theta)
            results.append(result)
    
    # Create DataFrame and save results to CSV
    df = pd.DataFrame(results)
    df.to_csv("final_simulation_results.csv", index=False)
    print("Final simulation results saved to final_simulation_results.csv")
    return df

if __name__ == "__main__":
    df = main_simulation()
# Out:
# Final results for R = 1.4 Å, Theta = 90°:
#   O1_x momentum = 2.862e+02 a.u..
#   OSO angle = 125.40°
#
# Final results for R = 1.4 Å, Theta = 95°:
#   O1_x momentum = 2.897e+02 a.u..
#   OSO angle = 124.52°
#
# Final results for R = 1.4 Å, Theta = 100°:
#   O1_x momentum = 2.941e+02 a.u..
#   OSO angle = 123.49°
#
# Final results for R = 1.4 Å, Theta = 105°:
#   O1_x momentum = 2.993e+02 a.u..
#   OSO angle = 122.31°
#
# Final results for R = 1.4 Å, Theta = 110°:
#   O1_x momentum = 3.052e+02 a.u..
#   OSO angle = 120.99°
#
# Final results for R = 1.4 Å, Theta = 115°:
#   O1_x momentum = 3.118e+02 a.u..
#   OSO angle = 119.54°
#
# Final results for R = 1.4 Å, Theta = 120°:
#   O1_x momentum = 3.188e+02 a.u..
#   OSO angle = 117.96°
#
# Final results for R = 1.4 Å, Theta = 125°:
#   O1_x momentum = 3.264e+02 a.u..
#   OSO angle = 116.25°
#
# Final results for R = 1.4 Å, Theta = 130°:
#   O1_x momentum = 3.343e+02 a.u..
#   OSO angle = 114.41°
#
# Final results for R = 1.4 Å, Theta = 135°:
#   O1_x momentum = 3.424e+02 a.u..
#   OSO angle = 112.46°
#
# Final results for R = 1.7 Å, Theta = 90°:
#   O1_x momentum = 2.598e+02 a.u..
#   OSO angle = 125.40°
#
# Final results for R = 1.7 Å, Theta = 95°:
#   O1_x momentum = 2.630e+02 a.u..
#   OSO angle = 124.52°
#
# Final results for R = 1.7 Å, Theta = 100°:
#   O1_x momentum = 2.670e+02 a.u..
#   OSO angle = 123.49°
#
# Final results for R = 1.7 Å, Theta = 105°:
#   O1_x momentum = 2.717e+02 a.u..
#   OSO angle = 122.31°
#
# Final results for R = 1.7 Å, Theta = 110°:
#   O1_x momentum = 2.770e+02 a.u..
#   OSO angle = 120.99°
#
# Final results for R = 1.7 Å, Theta = 115°:
#   O1_x momentum = 2.829e+02 a.u..
#   OSO angle = 119.54°
#
# Final results for R = 1.7 Å, Theta = 120°:
#   O1_x momentum = 2.894e+02 a.u..
#   OSO angle = 117.95°
#
# Final results for R = 1.7 Å, Theta = 125°:
#   O1_x momentum = 2.962e+02 a.u..
#   OSO angle = 116.25°
#
# Final results for R = 1.7 Å, Theta = 130°:
#   O1_x momentum = 3.034e+02 a.u..
#   OSO angle = 114.41°
#
# Final results for R = 1.7 Å, Theta = 135°:
#   O1_x momentum = 3.108e+02 a.u..
#   OSO angle = 112.46°
#
# Final results for R = 2.0 Å, Theta = 90°:
#   O1_x momentum = 2.395e+02 a.u..
#   OSO angle = 125.40°
#
# Final results for R = 2.0 Å, Theta = 95°:
#   O1_x momentum = 2.424e+02 a.u..
#   OSO angle = 124.52°
#
# Final results for R = 2.0 Å, Theta = 100°:
#   O1_x momentum = 2.461e+02 a.u..
#   OSO angle = 123.49°
#
# Final results for R = 2.0 Å, Theta = 105°:
#   O1_x momentum = 2.505e+02 a.u..
#   OSO angle = 122.31°
#
# Final results for R = 2.0 Å, Theta = 110°:
#   O1_x momentum = 2.554e+02 a.u..
#   OSO angle = 120.99°
#
# Final results for R = 2.0 Å, Theta = 115°:
#   O1_x momentum = 2.609e+02 a.u..
#   OSO angle = 119.54°
#
# Final results for R = 2.0 Å, Theta = 120°:
#   O1_x momentum = 2.668e+02 a.u..
#   OSO angle = 117.95°
#
# Final results for R = 2.0 Å, Theta = 125°:
#   O1_x momentum = 2.731e+02 a.u..
#   OSO angle = 116.25°
#
# Final results for R = 2.0 Å, Theta = 130°:
#   O1_x momentum = 2.797e+02 a.u..
#   OSO angle = 114.41°
#
# Final results for R = 2.0 Å, Theta = 135°:
#   O1_x momentum = 2.865e+02 a.u..
#   OSO angle = 112.46°
#
# Final results for R = 2.3 Å, Theta = 90°:
#   O1_x momentum = 2.233e+02 a.u..
#   OSO angle = 125.40°
#
# Final results for R = 2.3 Å, Theta = 95°:
#   O1_x momentum = 2.261e+02 a.u..
#   OSO angle = 124.52°
#
# Final results for R = 2.3 Å, Theta = 100°:
#   O1_x momentum = 2.295e+02 a.u..
#   OSO angle = 123.49°
#
# Final results for R = 2.3 Å, Theta = 105°:
#   O1_x momentum = 2.336e+02 a.u..
#   OSO angle = 122.31°
#
# Final results for R = 2.3 Å, Theta = 110°:
#   O1_x momentum = 2.382e+02 a.u..
#   OSO angle = 120.99°
#
# Final results for R = 2.3 Å, Theta = 115°:
#   O1_x momentum = 2.433e+02 a.u..
#   OSO angle = 119.54°
#
# Final results for R = 2.3 Å, Theta = 120°:
#   O1_x momentum = 2.488e+02 a.u..
#   OSO angle = 117.95°
#
# Final results for R = 2.3 Å, Theta = 125°:
#   O1_x momentum = 2.547e+02 a.u..
#   OSO angle = 116.25°
#
# Final results for R = 2.3 Å, Theta = 130°:
#   O1_x momentum = 2.608e+02 a.u..
#   OSO angle = 114.41°
#
# Final results for R = 2.3 Å, Theta = 135°:
#   O1_x momentum = 2.672e+02 a.u..
#   OSO angle = 112.46°
#
# Final results for R = 2.6 Å, Theta = 90°:
#   O1_x momentum = 2.101e+02 a.u..
#   OSO angle = 125.40°
#
# Final results for R = 2.6 Å, Theta = 95°:
#   O1_x momentum = 2.126e+02 a.u..
#   OSO angle = 124.52°
#
# Final results for R = 2.6 Å, Theta = 100°:
#   O1_x momentum = 2.159e+02 a.u..
#   OSO angle = 123.49°
#
# Final results for R = 2.6 Å, Theta = 105°:
#   O1_x momentum = 2.197e+02 a.u..
#   OSO angle = 122.31°
#
# Final results for R = 2.6 Å, Theta = 110°:
#   O1_x momentum = 2.240e+02 a.u..
#   OSO angle = 120.99°
#
# Final results for R = 2.6 Å, Theta = 115°:
#   O1_x momentum = 2.288e+02 a.u..
#   OSO angle = 119.54°
#
# Final results for R = 2.6 Å, Theta = 120°:
#   O1_x momentum = 2.340e+02 a.u..
#   OSO angle = 117.95°
#
# Final results for R = 2.6 Å, Theta = 125°:
#   O1_x momentum = 2.395e+02 a.u..
#   OSO angle = 116.25°
#
# Final results for R = 2.6 Å, Theta = 130°:
#   O1_x momentum = 2.453e+02 a.u..
#   OSO angle = 114.41°
#
# Final results for R = 2.6 Å, Theta = 135°:
#   O1_x momentum = 2.513e+02 a.u..
#   OSO angle = 112.45°
#
# Final results for R = 2.9000000000000004 Å, Theta = 90°:
#   O1_x momentum = 1.989e+02 a.u..
#   OSO angle = 125.40°
#
# Final results for R = 2.9000000000000004 Å, Theta = 95°:
#   O1_x momentum = 2.013e+02 a.u..
#   OSO angle = 124.52°
#
# Final results for R = 2.9000000000000004 Å, Theta = 100°:
#   O1_x momentum = 2.044e+02 a.u..
#   OSO angle = 123.49°
#
# Final results for R = 2.9000000000000004 Å, Theta = 105°:
#   O1_x momentum = 2.080e+02 a.u..
#   OSO angle = 122.31°
#
# Final results for R = 2.9000000000000004 Å, Theta = 110°:
#   O1_x momentum = 2.121e+02 a.u..
#   OSO angle = 120.99°
#
# Final results for R = 2.9000000000000004 Å, Theta = 115°:
#   O1_x momentum = 2.166e+02 a.u..
#   OSO angle = 119.54°
#
# Final results for R = 2.9000000000000004 Å, Theta = 120°:
#   O1_x momentum = 2.215e+02 a.u..
#   OSO angle = 117.95°
#
# Final results for R = 2.9000000000000004 Å, Theta = 125°:
#   O1_x momentum = 2.268e+02 a.u..
#   OSO angle = 116.25°
#
# Final results for R = 2.9000000000000004 Å, Theta = 130°:
#   O1_x momentum = 2.323e+02 a.u..
#   OSO angle = 114.41°
#
# Final results for R = 2.9000000000000004 Å, Theta = 135°:
#   O1_x momentum = 2.379e+02 a.u..
#   OSO angle = 112.45°
#
# Final results for R = 3.2 Å, Theta = 90°:
#   O1_x momentum = 1.893e+02 a.u..
#   OSO angle = 125.40°
#
# Final results for R = 3.2 Å, Theta = 95°:
#   O1_x momentum = 1.917e+02 a.u..
#   OSO angle = 124.52°
#
# Final results for R = 3.2 Å, Theta = 100°:
#   O1_x momentum = 1.946e+02 a.u..
#   OSO angle = 123.49°
#
# Final results for R = 3.2 Å, Theta = 105°:
#   O1_x momentum = 1.980e+02 a.u..
#   OSO angle = 122.31°
#
# Final results for R = 3.2 Å, Theta = 110°:
#   O1_x momentum = 2.019e+02 a.u..
#   OSO angle = 120.99°
#
# Final results for R = 3.2 Å, Theta = 115°:
#   O1_x momentum = 2.062e+02 a.u..
#   OSO angle = 119.54°
#
# Final results for R = 3.2 Å, Theta = 120°:
#   O1_x momentum = 2.109e+02 a.u..
#   OSO angle = 117.95°
#
# Final results for R = 3.2 Å, Theta = 125°:
#   O1_x momentum = 2.159e+02 a.u..
#   OSO angle = 116.25°
#
# Final results for R = 3.2 Å, Theta = 130°:
#   O1_x momentum = 2.211e+02 a.u..
#   OSO angle = 114.41°
#
# Final results for R = 3.2 Å, Theta = 135°:
#   O1_x momentum = 2.265e+02 a.u..
#   OSO angle = 112.45°
#
# Final simulation results saved to final_simulation_results.csv
