# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import os

os.chdir(r'\\chem.ox.ac.uk\Research\Vallance Claire\Zhihao\Data\COS\Simulation\3_fold_simulation\S3_O1_C1\Scan')

# Constants
k = 8.987155e9          # Coulomb constant [N m² C⁻²]
dt = 0.5 * 1e-15              # Time step in seconds
num_steps = 500000       # Number of integration steps

# Masses (in kg)
m1 = 12.0 * 1.67377e-27  # Mass of ion 1
m2 = 16.0 * 1.67377e-27  # Mass of ion 2
m3 = 32.0 * 1.67377e-27  # Mass of ion 3

# Charges (in Coulombs)
Q1 = 1 * 1.602e-19      # Charge of ion 1
Q2 = 1 * 1.602e-19      # Charge of ion 2
Q3 = 3 * 1.602e-19      # Charge of ion 3

# %%
def calculate_acceleration(r1, r2, r3, Q1_t, Q2_t, Q3_t):
    """
    Calculate the acceleration of each ion due to Coulomb forces.
    """
    # Pre-calculate difference vectors and their norms
    diff12 = r1 - r2
    diff13 = r1 - r3
    diff21 = -diff12   # r2 - r1
    diff23 = r2 - r3
    diff31 = -diff13   # r3 - r1
    diff32 = -diff23   # r3 - r2

    # Compute norms raised to the third power
    norm12_cubed = np.linalg.norm(diff12)**3
    norm13_cubed = np.linalg.norm(diff13)**3
    norm23_cubed = np.linalg.norm(diff23)**3

    # Calculate accelerations using Coulomb force law
    a1 = k / m1 * (Q1_t * Q2_t * diff12 / norm12_cubed +
                   Q1_t * Q3_t * diff13 / norm13_cubed)
    a2 = k / m2 * (Q2_t * Q1_t * (-diff12) / norm12_cubed +
                   Q2_t * Q3_t * diff23 / norm23_cubed)
    a3 = k / m3 * (Q1_t * Q3_t * (-diff13) / norm13_cubed +
                   Q2_t * Q3_t * (-diff23) / norm23_cubed)
    return a1, a2, a3

def calculate_first_step_r(r, v, a):
    """Calculate the position at the first time step using the Verlet algorithm."""
    return r + v * dt + 0.5 * a * dt**2

def simulate_run(RCO, RCS):
    """
    Simulate the system for given initial geometry (R in Å).
    The Verlet integration loop is executed, and only the final momenta

    """
    factor = 1e-10  # Conversion from Å to m

    # Initial positions (in meters)
    r1 = np.array([0.0, 0.0])*factor
    r2 = np.array([RCO , 0.0])*factor
    r3 = np.array([-RCS , 0.0])*factor

    # Initial velocities (m/s)
    v1 = np.array([0.0, 0.0])
    v2 = np.array([0.0, 0.0])
    v3 = np.array([0.0, 0.0])

    # Initial acceleration and first step positions
    a1, a2, a3 = calculate_acceleration(r1, r2, r3, Q1, Q2, Q3)
    r1_new = calculate_first_step_r(r1, v1, a1)
    r2_new = calculate_first_step_r(r2, v2, a2)
    r3_new = calculate_first_step_r(r3, v3, a3)

    # Initialize positions for Verlet integration
    r1_old, r2_old, r3_old = r1, r2, r3
    r1_now, r2_now, r3_now = r1_new, r2_new, r3_new

    # Verlet integration loop
    for step in range(2, num_steps):
        a1_now, a2_now, a3_now = calculate_acceleration(r1_now, r2_now, r3_now, Q1, Q2, Q3)
        r1_new = 2 * r1_now - r1_old + a1_now * dt**2
        r2_new = 2 * r2_now - r2_old + a2_now * dt**2
        r3_new = 2 * r3_now - r3_old + a3_now * dt**2

        # Update velocities (central difference)
        v1 = 0.5 * (r1_new - r1_old) / dt
        v2 = 0.5 * (r2_new - r2_old) / dt
        v3 = 0.5 * (r3_new - r3_old) / dt

        # Prepare for next iteration
        r1_old, r2_old, r3_old = r1_now, r2_now, r3_now
        r1_now, r2_now, r3_now = r1_new, r2_new, r3_new

    # # Final momenta (in kg·m/s)
    # P1 = m1 * np.linalg.norm(v1)
    # P2 = m2 * np.linalg.norm(v2)
    # P3 = m3 * np.linalg.norm(v3)
    # # Convert momenta to atomic units (1 a.u. = 1.99285e-24 kg·m/s)
    # P1_au = P1 / (1.99285e-24)
    # P2_au = P2 / (1.99285e-24)
    # P3_au = P3 / (1.99285e-24)


    # Calculate momentum components for each ion
    p1_x_au = m1 * v1[0]/ (1.99285e-24)
    p2_x_au = m2 * v2[0]/ (1.99285e-24)
    p3_x_au = m3 * v3[0]/ (1.99285e-24)


    # Print final result for this run
    print(f"Final results for RCO = {RCO} Å, RCS = {RCS} Å:")
    print(f"  C momentum = {p1_x_au:.3e} a.u.")
    print(f"  O momentum = {p2_x_au:.3e} a.u.")
    print(f"  S momentum = {p3_x_au:.3e} a.u.")

    #print(f"  S momentum = {P1_au:.3e} a.u., O1 momentum = {P2_au:.3e} a.u., O2 momentum = {P3_au:.3e} a.u.")
   

    return {
        'R_CO': RCO,
        'R_CS': RCS,
        'momentum_C_x_au': p1_x_au,
        'momentum_O_x_au': p2_x_au,
        'momentum_S_x_au': p3_x_au,
    }

# %%
def main_simulation():
    """
    Run the simulation for a range of RCO and RCS values, collect the final results,
    and save them to a CSV file.
    """
    results = []
    for RCO in np.arange(1.1, 2.8, 0.1):
        for RCS in np.arange(1.5, 3.2, 0.1):
            result = simulate_run(RCO, RCS)
            results.append(result)
    
    # Create DataFrame and save results to CSV
    df = pd.DataFrame(results)
    df.to_csv("final_simulation_results.csv", index=False)
    print("OCS_ions_info.csv")
    return df

if __name__ == "__main__":
    df = main_simulation()
# Out:
# Final results for RCO = 1.1 Å, RCS = 1.5 Å:
#   C momentum = 6.524e+01 a.u.
#   O momentum = 2.602e+02 a.u.
#   S momentum = -3.255e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 1.6 Å:
#   C momentum = 6.492e+01 a.u.
#   O momentum = 2.542e+02 a.u.
#   S momentum = -3.191e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 6.458e+01 a.u.
#   O momentum = 2.487e+02 a.u.
#   S momentum = -3.133e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 6.425e+01 a.u.
#   O momentum = 2.437e+02 a.u.
#   S momentum = -3.079e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 6.391e+01 a.u.
#   O momentum = 2.391e+02 a.u.
#   S momentum = -3.030e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 6.358e+01 a.u.
#   O momentum = 2.348e+02 a.u.
#   S momentum = -2.984e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 6.326e+01 a.u.
#   O momentum = 2.308e+02 a.u.
#   S momentum = -2.941e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 6.294e+01 a.u.
#   O momentum = 2.272e+02 a.u.
#   S momentum = -2.901e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 6.263e+01 a.u.
#   O momentum = 2.237e+02 a.u.
#   S momentum = -2.864e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 2.400000000000001 Å:
#   C momentum = 6.233e+01 a.u.
#   O momentum = 2.205e+02 a.u.
#   S momentum = -2.829e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 2.500000000000001 Å:
#   C momentum = 6.204e+01 a.u.
#   O momentum = 2.175e+02 a.u.
#   S momentum = -2.796e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 2.600000000000001 Å:
#   C momentum = 6.176e+01 a.u.
#   O momentum = 2.147e+02 a.u.
#   S momentum = -2.764e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 2.700000000000001 Å:
#   C momentum = 6.149e+01 a.u.
#   O momentum = 2.120e+02 a.u.
#   S momentum = -2.735e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 2.800000000000001 Å:
#   C momentum = 6.123e+01 a.u.
#   O momentum = 2.095e+02 a.u.
#   S momentum = -2.707e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 6.098e+01 a.u.
#   O momentum = 2.071e+02 a.u.
#   S momentum = -2.681e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 6.073e+01 a.u.
#   O momentum = 2.048e+02 a.u.
#   S momentum = -2.656e+02 a.u.
# Final results for RCO = 1.1 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 6.050e+01 a.u.
#   O momentum = 2.027e+02 a.u.
#   S momentum = -2.632e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 1.5 Å:
#   C momentum = 6.281e+01 a.u.
#   O momentum = 2.573e+02 a.u.
#   S momentum = -3.201e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 1.6 Å:
#   C momentum = 6.256e+01 a.u.
#   O momentum = 2.512e+02 a.u.
#   S momentum = -3.138e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 6.228e+01 a.u.
#   O momentum = 2.457e+02 a.u.
#   S momentum = -3.080e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 6.199e+01 a.u.
#   O momentum = 2.407e+02 a.u.
#   S momentum = -3.027e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 6.170e+01 a.u.
#   O momentum = 2.361e+02 a.u.
#   S momentum = -2.978e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 6.141e+01 a.u.
#   O momentum = 2.318e+02 a.u.
#   S momentum = -2.932e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 6.111e+01 a.u.
#   O momentum = 2.278e+02 a.u.
#   S momentum = -2.889e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 6.082e+01 a.u.
#   O momentum = 2.241e+02 a.u.
#   S momentum = -2.850e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 6.054e+01 a.u.
#   O momentum = 2.207e+02 a.u.
#   S momentum = -2.812e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 2.400000000000001 Å:
#   C momentum = 6.026e+01 a.u.
#   O momentum = 2.175e+02 a.u.
#   S momentum = -2.778e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 2.500000000000001 Å:
#   C momentum = 5.999e+01 a.u.
#   O momentum = 2.145e+02 a.u.
#   S momentum = -2.745e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 2.600000000000001 Å:
#   C momentum = 5.973e+01 a.u.
#   O momentum = 2.116e+02 a.u.
#   S momentum = -2.714e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 2.700000000000001 Å:
#   C momentum = 5.947e+01 a.u.
#   O momentum = 2.090e+02 a.u.
#   S momentum = -2.684e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 2.800000000000001 Å:
#   C momentum = 5.922e+01 a.u.
#   O momentum = 2.064e+02 a.u.
#   S momentum = -2.656e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 5.898e+01 a.u.
#   O momentum = 2.040e+02 a.u.
#   S momentum = -2.630e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 5.875e+01 a.u.
#   O momentum = 2.018e+02 a.u.
#   S momentum = -2.605e+02 a.u.
# Final results for RCO = 1.2000000000000002 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 5.852e+01 a.u.
#   O momentum = 1.996e+02 a.u.
#   S momentum = -2.581e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 1.5 Å:
#   C momentum = 6.060e+01 a.u.
#   O momentum = 2.547e+02 a.u.
#   S momentum = -3.153e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 1.6 Å:
#   C momentum = 6.040e+01 a.u.
#   O momentum = 2.486e+02 a.u.
#   S momentum = -3.090e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 6.018e+01 a.u.
#   O momentum = 2.431e+02 a.u.
#   S momentum = -3.033e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 5.994e+01 a.u.
#   O momentum = 2.381e+02 a.u.
#   S momentum = -2.980e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 5.969e+01 a.u.
#   O momentum = 2.334e+02 a.u.
#   S momentum = -2.931e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 5.943e+01 a.u.
#   O momentum = 2.291e+02 a.u.
#   S momentum = -2.886e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 5.917e+01 a.u.
#   O momentum = 2.252e+02 a.u.
#   S momentum = -2.844e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 5.891e+01 a.u.
#   O momentum = 2.215e+02 a.u.
#   S momentum = -2.804e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 5.865e+01 a.u.
#   O momentum = 2.181e+02 a.u.
#   S momentum = -2.767e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 2.400000000000001 Å:
#   C momentum = 5.840e+01 a.u.
#   O momentum = 2.148e+02 a.u.
#   S momentum = -2.732e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 2.500000000000001 Å:
#   C momentum = 5.814e+01 a.u.
#   O momentum = 2.118e+02 a.u.
#   S momentum = -2.699e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 2.600000000000001 Å:
#   C momentum = 5.790e+01 a.u.
#   O momentum = 2.090e+02 a.u.
#   S momentum = -2.669e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 2.700000000000001 Å:
#   C momentum = 5.766e+01 a.u.
#   O momentum = 2.063e+02 a.u.
#   S momentum = -2.639e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 2.800000000000001 Å:
#   C momentum = 5.742e+01 a.u.
#   O momentum = 2.037e+02 a.u.
#   S momentum = -2.612e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 5.719e+01 a.u.
#   O momentum = 2.013e+02 a.u.
#   S momentum = -2.585e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 5.697e+01 a.u.
#   O momentum = 1.991e+02 a.u.
#   S momentum = -2.560e+02 a.u.
# Final results for RCO = 1.3000000000000003 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 5.675e+01 a.u.
#   O momentum = 1.969e+02 a.u.
#   S momentum = -2.536e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 1.5 Å:
#   C momentum = 5.855e+01 a.u.
#   O momentum = 2.524e+02 a.u.
#   S momentum = -3.109e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 1.6 Å:
#   C momentum = 5.842e+01 a.u.
#   O momentum = 2.463e+02 a.u.
#   S momentum = -3.047e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 5.825e+01 a.u.
#   O momentum = 2.408e+02 a.u.
#   S momentum = -2.990e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 5.805e+01 a.u.
#   O momentum = 2.357e+02 a.u.
#   S momentum = -2.938e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 5.785e+01 a.u.
#   O momentum = 2.311e+02 a.u.
#   S momentum = -2.889e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 5.762e+01 a.u.
#   O momentum = 2.268e+02 a.u.
#   S momentum = -2.844e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 5.740e+01 a.u.
#   O momentum = 2.228e+02 a.u.
#   S momentum = -2.802e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 5.716e+01 a.u.
#   O momentum = 2.191e+02 a.u.
#   S momentum = -2.763e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 5.693e+01 a.u.
#   O momentum = 2.157e+02 a.u.
#   S momentum = -2.726e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 2.400000000000001 Å:
#   C momentum = 5.670e+01 a.u.
#   O momentum = 2.125e+02 a.u.
#   S momentum = -2.692e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 2.500000000000001 Å:
#   C momentum = 5.647e+01 a.u.
#   O momentum = 2.094e+02 a.u.
#   S momentum = -2.659e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 2.600000000000001 Å:
#   C momentum = 5.624e+01 a.u.
#   O momentum = 2.066e+02 a.u.
#   S momentum = -2.628e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 2.700000000000001 Å:
#   C momentum = 5.601e+01 a.u.
#   O momentum = 2.039e+02 a.u.
#   S momentum = -2.599e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 2.800000000000001 Å:
#   C momentum = 5.579e+01 a.u.
#   O momentum = 2.014e+02 a.u.
#   S momentum = -2.571e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 5.558e+01 a.u.
#   O momentum = 1.990e+02 a.u.
#   S momentum = -2.545e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 5.537e+01 a.u.
#   O momentum = 1.967e+02 a.u.
#   S momentum = -2.520e+02 a.u.
# Final results for RCO = 1.4000000000000004 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 5.516e+01 a.u.
#   O momentum = 1.945e+02 a.u.
#   S momentum = -2.497e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 1.5 Å:
#   C momentum = 5.665e+01 a.u.
#   O momentum = 2.503e+02 a.u.
#   S momentum = -3.070e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 1.6 Å:
#   C momentum = 5.657e+01 a.u.
#   O momentum = 2.442e+02 a.u.
#   S momentum = -3.008e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 5.645e+01 a.u.
#   O momentum = 2.387e+02 a.u.
#   S momentum = -2.952e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 5.631e+01 a.u.
#   O momentum = 2.336e+02 a.u.
#   S momentum = -2.899e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 5.614e+01 a.u.
#   O momentum = 2.290e+02 a.u.
#   S momentum = -2.851e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 5.595e+01 a.u.
#   O momentum = 2.247e+02 a.u.
#   S momentum = -2.807e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 5.576e+01 a.u.
#   O momentum = 2.207e+02 a.u.
#   S momentum = -2.765e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 5.555e+01 a.u.
#   O momentum = 2.170e+02 a.u.
#   S momentum = -2.726e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 5.535e+01 a.u.
#   O momentum = 2.136e+02 a.u.
#   S momentum = -2.689e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 2.400000000000001 Å:
#   C momentum = 5.514e+01 a.u.
#   O momentum = 2.103e+02 a.u.
#   S momentum = -2.655e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 2.500000000000001 Å:
#   C momentum = 5.492e+01 a.u.
#   O momentum = 2.073e+02 a.u.
#   S momentum = -2.622e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 2.600000000000001 Å:
#   C momentum = 5.471e+01 a.u.
#   O momentum = 2.045e+02 a.u.
#   S momentum = -2.592e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 2.700000000000001 Å:
#   C momentum = 5.451e+01 a.u.
#   O momentum = 2.018e+02 a.u.
#   S momentum = -2.563e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 2.800000000000001 Å:
#   C momentum = 5.430e+01 a.u.
#   O momentum = 1.992e+02 a.u.
#   S momentum = -2.535e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 5.410e+01 a.u.
#   O momentum = 1.968e+02 a.u.
#   S momentum = -2.509e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 5.390e+01 a.u.
#   O momentum = 1.945e+02 a.u.
#   S momentum = -2.484e+02 a.u.
# Final results for RCO = 1.5000000000000004 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 5.371e+01 a.u.
#   O momentum = 1.924e+02 a.u.
#   S momentum = -2.461e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 1.5 Å:
#   C momentum = 5.487e+01 a.u.
#   O momentum = 2.484e+02 a.u.
#   S momentum = -3.033e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 1.6 Å:
#   C momentum = 5.485e+01 a.u.
#   O momentum = 2.424e+02 a.u.
#   S momentum = -2.972e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 5.478e+01 a.u.
#   O momentum = 2.368e+02 a.u.
#   S momentum = -2.916e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 5.468e+01 a.u.
#   O momentum = 2.318e+02 a.u.
#   S momentum = -2.864e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 5.455e+01 a.u.
#   O momentum = 2.271e+02 a.u.
#   S momentum = -2.817e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 5.440e+01 a.u.
#   O momentum = 2.228e+02 a.u.
#   S momentum = -2.772e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 5.423e+01 a.u.
#   O momentum = 2.188e+02 a.u.
#   S momentum = -2.731e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 5.406e+01 a.u.
#   O momentum = 2.151e+02 a.u.
#   S momentum = -2.692e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 5.388e+01 a.u.
#   O momentum = 2.117e+02 a.u.
#   S momentum = -2.656e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 2.400000000000001 Å:
#   C momentum = 5.369e+01 a.u.
#   O momentum = 2.084e+02 a.u.
#   S momentum = -2.621e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 2.500000000000001 Å:
#   C momentum = 5.350e+01 a.u.
#   O momentum = 2.054e+02 a.u.
#   S momentum = -2.589e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 2.600000000000001 Å:
#   C momentum = 5.331e+01 a.u.
#   O momentum = 2.025e+02 a.u.
#   S momentum = -2.559e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 2.700000000000001 Å:
#   C momentum = 5.312e+01 a.u.
#   O momentum = 1.999e+02 a.u.
#   S momentum = -2.530e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 2.800000000000001 Å:
#   C momentum = 5.293e+01 a.u.
#   O momentum = 1.973e+02 a.u.
#   S momentum = -2.502e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 5.274e+01 a.u.
#   O momentum = 1.949e+02 a.u.
#   S momentum = -2.476e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 5.255e+01 a.u.
#   O momentum = 1.926e+02 a.u.
#   S momentum = -2.452e+02 a.u.
# Final results for RCO = 1.6000000000000005 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 5.237e+01 a.u.
#   O momentum = 1.904e+02 a.u.
#   S momentum = -2.428e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 1.5 Å:
#   C momentum = 5.320e+01 a.u.
#   O momentum = 2.468e+02 a.u.
#   S momentum = -3.000e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 1.6 Å:
#   C momentum = 5.323e+01 a.u.
#   O momentum = 2.407e+02 a.u.
#   S momentum = -2.939e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 5.321e+01 a.u.
#   O momentum = 2.351e+02 a.u.
#   S momentum = -2.883e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 5.315e+01 a.u.
#   O momentum = 2.301e+02 a.u.
#   S momentum = -2.832e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 5.306e+01 a.u.
#   O momentum = 2.254e+02 a.u.
#   S momentum = -2.785e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 5.294e+01 a.u.
#   O momentum = 2.211e+02 a.u.
#   S momentum = -2.740e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 5.281e+01 a.u.
#   O momentum = 2.171e+02 a.u.
#   S momentum = -2.699e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 5.266e+01 a.u.
#   O momentum = 2.134e+02 a.u.
#   S momentum = -2.661e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 5.251e+01 a.u.
#   O momentum = 2.099e+02 a.u.
#   S momentum = -2.625e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 2.400000000000001 Å:
#   C momentum = 5.234e+01 a.u.
#   O momentum = 2.067e+02 a.u.
#   S momentum = -2.590e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 2.500000000000001 Å:
#   C momentum = 5.217e+01 a.u.
#   O momentum = 2.037e+02 a.u.
#   S momentum = -2.558e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 2.600000000000001 Å:
#   C momentum = 5.200e+01 a.u.
#   O momentum = 2.008e+02 a.u.
#   S momentum = -2.528e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 2.700000000000001 Å:
#   C momentum = 5.183e+01 a.u.
#   O momentum = 1.981e+02 a.u.
#   S momentum = -2.499e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 2.800000000000001 Å:
#   C momentum = 5.165e+01 a.u.
#   O momentum = 1.956e+02 a.u.
#   S momentum = -2.472e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 5.148e+01 a.u.
#   O momentum = 1.931e+02 a.u.
#   S momentum = -2.446e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 5.130e+01 a.u.
#   O momentum = 1.908e+02 a.u.
#   S momentum = -2.422e+02 a.u.
# Final results for RCO = 1.7000000000000006 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 5.113e+01 a.u.
#   O momentum = 1.887e+02 a.u.
#   S momentum = -2.398e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 1.5 Å:
#   C momentum = 5.163e+01 a.u.
#   O momentum = 2.452e+02 a.u.
#   S momentum = -2.969e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 1.6 Å:
#   C momentum = 5.171e+01 a.u.
#   O momentum = 2.391e+02 a.u.
#   S momentum = -2.908e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 5.173e+01 a.u.
#   O momentum = 2.336e+02 a.u.
#   S momentum = -2.853e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 5.171e+01 a.u.
#   O momentum = 2.285e+02 a.u.
#   S momentum = -2.802e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 5.166e+01 a.u.
#   O momentum = 2.238e+02 a.u.
#   S momentum = -2.755e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 5.158e+01 a.u.
#   O momentum = 2.195e+02 a.u.
#   S momentum = -2.711e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 5.147e+01 a.u.
#   O momentum = 2.155e+02 a.u.
#   S momentum = -2.670e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 5.135e+01 a.u.
#   O momentum = 2.118e+02 a.u.
#   S momentum = -2.632e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 5.122e+01 a.u.
#   O momentum = 2.084e+02 a.u.
#   S momentum = -2.596e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 2.400000000000001 Å:
#   C momentum = 5.108e+01 a.u.
#   O momentum = 2.051e+02 a.u.
#   S momentum = -2.562e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 2.500000000000001 Å:
#   C momentum = 5.093e+01 a.u.
#   O momentum = 2.021e+02 a.u.
#   S momentum = -2.530e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 2.600000000000001 Å:
#   C momentum = 5.078e+01 a.u.
#   O momentum = 1.992e+02 a.u.
#   S momentum = -2.500e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 2.700000000000001 Å:
#   C momentum = 5.062e+01 a.u.
#   O momentum = 1.965e+02 a.u.
#   S momentum = -2.471e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 2.800000000000001 Å:
#   C momentum = 5.046e+01 a.u.
#   O momentum = 1.940e+02 a.u.
#   S momentum = -2.444e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 5.030e+01 a.u.
#   O momentum = 1.915e+02 a.u.
#   S momentum = -2.418e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 5.014e+01 a.u.
#   O momentum = 1.893e+02 a.u.
#   S momentum = -2.394e+02 a.u.
# Final results for RCO = 1.8000000000000007 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 4.998e+01 a.u.
#   O momentum = 1.871e+02 a.u.
#   S momentum = -2.370e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 1.5 Å:
#   C momentum = 5.014e+01 a.u.
#   O momentum = 2.438e+02 a.u.
#   S momentum = -2.940e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 1.6 Å:
#   C momentum = 5.027e+01 a.u.
#   O momentum = 2.377e+02 a.u.
#   S momentum = -2.880e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 5.034e+01 a.u.
#   O momentum = 2.322e+02 a.u.
#   S momentum = -2.825e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 5.035e+01 a.u.
#   O momentum = 2.271e+02 a.u.
#   S momentum = -2.774e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 5.033e+01 a.u.
#   O momentum = 2.224e+02 a.u.
#   S momentum = -2.727e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 5.028e+01 a.u.
#   O momentum = 2.181e+02 a.u.
#   S momentum = -2.684e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 5.021e+01 a.u.
#   O momentum = 2.141e+02 a.u.
#   S momentum = -2.643e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 5.012e+01 a.u.
#   O momentum = 2.104e+02 a.u.
#   S momentum = -2.605e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 5.001e+01 a.u.
#   O momentum = 2.069e+02 a.u.
#   S momentum = -2.569e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 2.400000000000001 Å:
#   C momentum = 4.989e+01 a.u.
#   O momentum = 2.037e+02 a.u.
#   S momentum = -2.536e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 2.500000000000001 Å:
#   C momentum = 4.976e+01 a.u.
#   O momentum = 2.006e+02 a.u.
#   S momentum = -2.504e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 2.600000000000001 Å:
#   C momentum = 4.962e+01 a.u.
#   O momentum = 1.978e+02 a.u.
#   S momentum = -2.474e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 2.700000000000001 Å:
#   C momentum = 4.948e+01 a.u.
#   O momentum = 1.951e+02 a.u.
#   S momentum = -2.445e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 2.800000000000001 Å:
#   C momentum = 4.934e+01 a.u.
#   O momentum = 1.925e+02 a.u.
#   S momentum = -2.418e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 4.919e+01 a.u.
#   O momentum = 1.901e+02 a.u.
#   S momentum = -2.393e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 4.905e+01 a.u.
#   O momentum = 1.878e+02 a.u.
#   S momentum = -2.368e+02 a.u.
# Final results for RCO = 1.9000000000000008 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 4.890e+01 a.u.
#   O momentum = 1.856e+02 a.u.
#   S momentum = -2.345e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 1.5 Å:
#   C momentum = 4.873e+01 a.u.
#   O momentum = 2.425e+02 a.u.
#   S momentum = -2.913e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 1.6 Å:
#   C momentum = 4.890e+01 a.u.
#   O momentum = 2.364e+02 a.u.
#   S momentum = -2.853e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 4.901e+01 a.u.
#   O momentum = 2.309e+02 a.u.
#   S momentum = -2.799e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 4.906e+01 a.u.
#   O momentum = 2.258e+02 a.u.
#   S momentum = -2.748e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 4.908e+01 a.u.
#   O momentum = 2.211e+02 a.u.
#   S momentum = -2.702e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 4.906e+01 a.u.
#   O momentum = 2.168e+02 a.u.
#   S momentum = -2.658e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 4.901e+01 a.u.
#   O momentum = 2.128e+02 a.u.
#   S momentum = -2.618e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 4.895e+01 a.u.
#   O momentum = 2.091e+02 a.u.
#   S momentum = -2.580e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 4.886e+01 a.u.
#   O momentum = 2.056e+02 a.u.
#   S momentum = -2.544e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 2.400000000000001 Å:
#   C momentum = 4.876e+01 a.u.
#   O momentum = 2.023e+02 a.u.
#   S momentum = -2.511e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 2.500000000000001 Å:
#   C momentum = 4.865e+01 a.u.
#   O momentum = 1.993e+02 a.u.
#   S momentum = -2.479e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 2.600000000000001 Å:
#   C momentum = 4.854e+01 a.u.
#   O momentum = 1.964e+02 a.u.
#   S momentum = -2.450e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 2.700000000000001 Å:
#   C momentum = 4.841e+01 a.u.
#   O momentum = 1.937e+02 a.u.
#   S momentum = -2.421e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 2.800000000000001 Å:
#   C momentum = 4.829e+01 a.u.
#   O momentum = 1.912e+02 a.u.
#   S momentum = -2.394e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 4.815e+01 a.u.
#   O momentum = 1.887e+02 a.u.
#   S momentum = -2.369e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 4.802e+01 a.u.
#   O momentum = 1.864e+02 a.u.
#   S momentum = -2.345e+02 a.u.
# Final results for RCO = 2.000000000000001 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 4.788e+01 a.u.
#   O momentum = 1.842e+02 a.u.
#   S momentum = -2.321e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 1.5 Å:
#   C momentum = 4.739e+01 a.u.
#   O momentum = 2.414e+02 a.u.
#   S momentum = -2.887e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 1.6 Å:
#   C momentum = 4.760e+01 a.u.
#   O momentum = 2.352e+02 a.u.
#   S momentum = -2.828e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 4.775e+01 a.u.
#   O momentum = 2.296e+02 a.u.
#   S momentum = -2.774e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 4.784e+01 a.u.
#   O momentum = 2.246e+02 a.u.
#   S momentum = -2.724e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 4.788e+01 a.u.
#   O momentum = 2.199e+02 a.u.
#   S momentum = -2.678e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 4.790e+01 a.u.
#   O momentum = 2.156e+02 a.u.
#   S momentum = -2.634e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 4.788e+01 a.u.
#   O momentum = 2.115e+02 a.u.
#   S momentum = -2.594e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 4.783e+01 a.u.
#   O momentum = 2.078e+02 a.u.
#   S momentum = -2.557e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 4.777e+01 a.u.
#   O momentum = 2.044e+02 a.u.
#   S momentum = -2.521e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 2.400000000000001 Å:
#   C momentum = 4.770e+01 a.u.
#   O momentum = 2.011e+02 a.u.
#   S momentum = -2.488e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 2.500000000000001 Å:
#   C momentum = 4.761e+01 a.u.
#   O momentum = 1.980e+02 a.u.
#   S momentum = -2.457e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 2.600000000000001 Å:
#   C momentum = 4.751e+01 a.u.
#   O momentum = 1.952e+02 a.u.
#   S momentum = -2.427e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 2.700000000000001 Å:
#   C momentum = 4.740e+01 a.u.
#   O momentum = 1.925e+02 a.u.
#   S momentum = -2.399e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 2.800000000000001 Å:
#   C momentum = 4.729e+01 a.u.
#   O momentum = 1.899e+02 a.u.
#   S momentum = -2.372e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 4.717e+01 a.u.
#   O momentum = 1.875e+02 a.u.
#   S momentum = -2.347e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 4.705e+01 a.u.
#   O momentum = 1.852e+02 a.u.
#   S momentum = -2.322e+02 a.u.
# Final results for RCO = 2.100000000000001 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 4.693e+01 a.u.
#   O momentum = 1.830e+02 a.u.
#   S momentum = -2.299e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 1.5 Å:
#   C momentum = 4.611e+01 a.u.
#   O momentum = 2.403e+02 a.u.
#   S momentum = -2.864e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 1.6 Å:
#   C momentum = 4.636e+01 a.u.
#   O momentum = 2.341e+02 a.u.
#   S momentum = -2.805e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 4.654e+01 a.u.
#   O momentum = 2.285e+02 a.u.
#   S momentum = -2.751e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 4.667e+01 a.u.
#   O momentum = 2.234e+02 a.u.
#   S momentum = -2.701e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 4.675e+01 a.u.
#   O momentum = 2.187e+02 a.u.
#   S momentum = -2.655e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 4.679e+01 a.u.
#   O momentum = 2.144e+02 a.u.
#   S momentum = -2.612e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 4.679e+01 a.u.
#   O momentum = 2.104e+02 a.u.
#   S momentum = -2.572e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 4.678e+01 a.u.
#   O momentum = 2.067e+02 a.u.
#   S momentum = -2.535e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 4.674e+01 a.u.
#   O momentum = 2.032e+02 a.u.
#   S momentum = -2.499e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 2.400000000000001 Å:
#   C momentum = 4.668e+01 a.u.
#   O momentum = 2.000e+02 a.u.
#   S momentum = -2.466e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 2.500000000000001 Å:
#   C momentum = 4.661e+01 a.u.
#   O momentum = 1.969e+02 a.u.
#   S momentum = -2.435e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 2.600000000000001 Å:
#   C momentum = 4.653e+01 a.u.
#   O momentum = 1.940e+02 a.u.
#   S momentum = -2.406e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 2.700000000000001 Å:
#   C momentum = 4.644e+01 a.u.
#   O momentum = 1.913e+02 a.u.
#   S momentum = -2.378e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 2.800000000000001 Å:
#   C momentum = 4.634e+01 a.u.
#   O momentum = 1.888e+02 a.u.
#   S momentum = -2.351e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 4.624e+01 a.u.
#   O momentum = 1.863e+02 a.u.
#   S momentum = -2.326e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 4.613e+01 a.u.
#   O momentum = 1.840e+02 a.u.
#   S momentum = -2.301e+02 a.u.
# Final results for RCO = 2.200000000000001 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 4.602e+01 a.u.
#   O momentum = 1.818e+02 a.u.
#   S momentum = -2.278e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 1.5 Å:
#   C momentum = 4.488e+01 a.u.
#   O momentum = 2.392e+02 a.u.
#   S momentum = -2.841e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 1.6 Å:
#   C momentum = 4.518e+01 a.u.
#   O momentum = 2.331e+02 a.u.
#   S momentum = -2.783e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 4.540e+01 a.u.
#   O momentum = 2.275e+02 a.u.
#   S momentum = -2.729e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 4.555e+01 a.u.
#   O momentum = 2.224e+02 a.u.
#   S momentum = -2.679e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 4.566e+01 a.u.
#   O momentum = 2.177e+02 a.u.
#   S momentum = -2.634e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 4.573e+01 a.u.
#   O momentum = 2.134e+02 a.u.
#   S momentum = -2.591e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 4.576e+01 a.u.
#   O momentum = 2.094e+02 a.u.
#   S momentum = -2.551e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 4.576e+01 a.u.
#   O momentum = 2.056e+02 a.u.
#   S momentum = -2.514e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 4.575e+01 a.u.
#   O momentum = 2.021e+02 a.u.
#   S momentum = -2.479e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 2.400000000000001 Å:
#   C momentum = 4.571e+01 a.u.
#   O momentum = 1.989e+02 a.u.
#   S momentum = -2.446e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 2.500000000000001 Å:
#   C momentum = 4.566e+01 a.u.
#   O momentum = 1.958e+02 a.u.
#   S momentum = -2.415e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 2.600000000000001 Å:
#   C momentum = 4.560e+01 a.u.
#   O momentum = 1.930e+02 a.u.
#   S momentum = -2.385e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 2.700000000000001 Å:
#   C momentum = 4.552e+01 a.u.
#   O momentum = 1.902e+02 a.u.
#   S momentum = -2.358e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 2.800000000000001 Å:
#   C momentum = 4.544e+01 a.u.
#   O momentum = 1.877e+02 a.u.
#   S momentum = -2.331e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 4.535e+01 a.u.
#   O momentum = 1.852e+02 a.u.
#   S momentum = -2.306e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 4.525e+01 a.u.
#   O momentum = 1.829e+02 a.u.
#   S momentum = -2.282e+02 a.u.
# Final results for RCO = 2.300000000000001 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 4.515e+01 a.u.
#   O momentum = 1.807e+02 a.u.
#   S momentum = -2.259e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 1.5 Å:
#   C momentum = 4.372e+01 a.u.
#   O momentum = 2.383e+02 a.u.
#   S momentum = -2.820e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 1.6 Å:
#   C momentum = 4.404e+01 a.u.
#   O momentum = 2.321e+02 a.u.
#   S momentum = -2.762e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 4.429e+01 a.u.
#   O momentum = 2.265e+02 a.u.
#   S momentum = -2.708e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 4.448e+01 a.u.
#   O momentum = 2.214e+02 a.u.
#   S momentum = -2.659e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 4.462e+01 a.u.
#   O momentum = 2.167e+02 a.u.
#   S momentum = -2.613e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 4.471e+01 a.u.
#   O momentum = 2.124e+02 a.u.
#   S momentum = -2.571e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 4.477e+01 a.u.
#   O momentum = 2.084e+02 a.u.
#   S momentum = -2.531e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 4.480e+01 a.u.
#   O momentum = 2.046e+02 a.u.
#   S momentum = -2.494e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 4.480e+01 a.u.
#   O momentum = 2.011e+02 a.u.
#   S momentum = -2.459e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 2.400000000000001 Å:
#   C momentum = 4.478e+01 a.u.
#   O momentum = 1.979e+02 a.u.
#   S momentum = -2.427e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 2.500000000000001 Å:
#   C momentum = 4.475e+01 a.u.
#   O momentum = 1.948e+02 a.u.
#   S momentum = -2.396e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 2.600000000000001 Å:
#   C momentum = 4.470e+01 a.u.
#   O momentum = 1.919e+02 a.u.
#   S momentum = -2.366e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 2.700000000000001 Å:
#   C momentum = 4.464e+01 a.u.
#   O momentum = 1.892e+02 a.u.
#   S momentum = -2.339e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 2.800000000000001 Å:
#   C momentum = 4.457e+01 a.u.
#   O momentum = 1.867e+02 a.u.
#   S momentum = -2.312e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 4.450e+01 a.u.
#   O momentum = 1.842e+02 a.u.
#   S momentum = -2.287e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 4.442e+01 a.u.
#   O momentum = 1.819e+02 a.u.
#   S momentum = -2.263e+02 a.u.
# Final results for RCO = 2.4000000000000012 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 4.433e+01 a.u.
#   O momentum = 1.797e+02 a.u.
#   S momentum = -2.241e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 1.5 Å:
#   C momentum = 4.260e+01 a.u.
#   O momentum = 2.374e+02 a.u.
#   S momentum = -2.800e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 1.6 Å:
#   C momentum = 4.296e+01 a.u.
#   O momentum = 2.312e+02 a.u.
#   S momentum = -2.742e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 4.324e+01 a.u.
#   O momentum = 2.256e+02 a.u.
#   S momentum = -2.689e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 4.346e+01 a.u.
#   O momentum = 2.205e+02 a.u.
#   S momentum = -2.640e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 4.362e+01 a.u.
#   O momentum = 2.158e+02 a.u.
#   S momentum = -2.594e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 4.374e+01 a.u.
#   O momentum = 2.115e+02 a.u.
#   S momentum = -2.552e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 4.382e+01 a.u.
#   O momentum = 2.074e+02 a.u.
#   S momentum = -2.513e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 4.387e+01 a.u.
#   O momentum = 2.037e+02 a.u.
#   S momentum = -2.476e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 4.389e+01 a.u.
#   O momentum = 2.002e+02 a.u.
#   S momentum = -2.441e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 2.400000000000001 Å:
#   C momentum = 4.389e+01 a.u.
#   O momentum = 1.970e+02 a.u.
#   S momentum = -2.408e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 2.500000000000001 Å:
#   C momentum = 4.388e+01 a.u.
#   O momentum = 1.939e+02 a.u.
#   S momentum = -2.378e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 2.600000000000001 Å:
#   C momentum = 4.385e+01 a.u.
#   O momentum = 1.910e+02 a.u.
#   S momentum = -2.349e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 2.700000000000001 Å:
#   C momentum = 4.380e+01 a.u.
#   O momentum = 1.883e+02 a.u.
#   S momentum = -2.321e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 2.800000000000001 Å:
#   C momentum = 4.375e+01 a.u.
#   O momentum = 1.857e+02 a.u.
#   S momentum = -2.295e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 4.369e+01 a.u.
#   O momentum = 1.833e+02 a.u.
#   S momentum = -2.270e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 4.361e+01 a.u.
#   O momentum = 1.810e+02 a.u.
#   S momentum = -2.246e+02 a.u.
# Final results for RCO = 2.5000000000000013 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 4.354e+01 a.u.
#   O momentum = 1.788e+02 a.u.
#   S momentum = -2.223e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 1.5 Å:
#   C momentum = 4.152e+01 a.u.
#   O momentum = 2.366e+02 a.u.
#   S momentum = -2.781e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 1.6 Å:
#   C momentum = 4.191e+01 a.u.
#   O momentum = 2.304e+02 a.u.
#   S momentum = -2.723e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 4.223e+01 a.u.
#   O momentum = 2.248e+02 a.u.
#   S momentum = -2.670e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 4.247e+01 a.u.
#   O momentum = 2.197e+02 a.u.
#   S momentum = -2.621e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 4.266e+01 a.u.
#   O momentum = 2.149e+02 a.u.
#   S momentum = -2.576e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 4.280e+01 a.u.
#   O momentum = 2.106e+02 a.u.
#   S momentum = -2.534e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 4.291e+01 a.u.
#   O momentum = 2.066e+02 a.u.
#   S momentum = -2.495e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 4.298e+01 a.u.
#   O momentum = 2.028e+02 a.u.
#   S momentum = -2.458e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 4.302e+01 a.u.
#   O momentum = 1.993e+02 a.u.
#   S momentum = -2.424e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 2.400000000000001 Å:
#   C momentum = 4.304e+01 a.u.
#   O momentum = 1.961e+02 a.u.
#   S momentum = -2.391e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 2.500000000000001 Å:
#   C momentum = 4.304e+01 a.u.
#   O momentum = 1.930e+02 a.u.
#   S momentum = -2.360e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 2.600000000000001 Å:
#   C momentum = 4.303e+01 a.u.
#   O momentum = 1.901e+02 a.u.
#   S momentum = -2.331e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 2.700000000000001 Å:
#   C momentum = 4.300e+01 a.u.
#   O momentum = 1.874e+02 a.u.
#   S momentum = -2.304e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 2.800000000000001 Å:
#   C momentum = 4.296e+01 a.u.
#   O momentum = 1.848e+02 a.u.
#   S momentum = -2.278e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 4.291e+01 a.u.
#   O momentum = 1.824e+02 a.u.
#   S momentum = -2.253e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 4.285e+01 a.u.
#   O momentum = 1.801e+02 a.u.
#   S momentum = -2.229e+02 a.u.
# Final results for RCO = 2.6000000000000014 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 4.278e+01 a.u.
#   O momentum = 1.779e+02 a.u.
#   S momentum = -2.207e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 1.5 Å:
#   C momentum = 4.049e+01 a.u.
#   O momentum = 2.358e+02 a.u.
#   S momentum = -2.763e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 1.6 Å:
#   C momentum = 4.091e+01 a.u.
#   O momentum = 2.296e+02 a.u.
#   S momentum = -2.705e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 1.7000000000000002 Å:
#   C momentum = 4.125e+01 a.u.
#   O momentum = 2.240e+02 a.u.
#   S momentum = -2.652e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 1.8000000000000003 Å:
#   C momentum = 4.152e+01 a.u.
#   O momentum = 2.189e+02 a.u.
#   S momentum = -2.604e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 1.9000000000000004 Å:
#   C momentum = 4.174e+01 a.u.
#   O momentum = 2.141e+02 a.u.
#   S momentum = -2.559e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 2.0000000000000004 Å:
#   C momentum = 4.190e+01 a.u.
#   O momentum = 2.098e+02 a.u.
#   S momentum = -2.517e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 2.1000000000000005 Å:
#   C momentum = 4.203e+01 a.u.
#   O momentum = 2.058e+02 a.u.
#   S momentum = -2.478e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 2.2000000000000006 Å:
#   C momentum = 4.212e+01 a.u.
#   O momentum = 2.020e+02 a.u.
#   S momentum = -2.441e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 2.3000000000000007 Å:
#   C momentum = 4.218e+01 a.u.
#   O momentum = 1.985e+02 a.u.
#   S momentum = -2.407e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 2.400000000000001 Å:
#   C momentum = 4.222e+01 a.u.
#   O momentum = 1.952e+02 a.u.
#   S momentum = -2.375e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 2.500000000000001 Å:
#   C momentum = 4.224e+01 a.u.
#   O momentum = 1.922e+02 a.u.
#   S momentum = -2.344e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 2.600000000000001 Å:
#   C momentum = 4.224e+01 a.u.
#   O momentum = 1.893e+02 a.u.
#   S momentum = -2.315e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 2.700000000000001 Å:
#   C momentum = 4.222e+01 a.u.
#   O momentum = 1.866e+02 a.u.
#   S momentum = -2.288e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 2.800000000000001 Å:
#   C momentum = 4.219e+01 a.u.
#   O momentum = 1.840e+02 a.u.
#   S momentum = -2.262e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 2.9000000000000012 Å:
#   C momentum = 4.216e+01 a.u.
#   O momentum = 1.816e+02 a.u.
#   S momentum = -2.237e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 3.0000000000000013 Å:
#   C momentum = 4.211e+01 a.u.
#   O momentum = 1.792e+02 a.u.
#   S momentum = -2.214e+02 a.u.
# Final results for RCO = 2.7000000000000015 Å, RCS = 3.1000000000000014 Å:
#   C momentum = 4.206e+01 a.u.
#   O momentum = 1.770e+02 a.u.
#   S momentum = -2.191e+02 a.u.
# OCS_ions_info.csv
